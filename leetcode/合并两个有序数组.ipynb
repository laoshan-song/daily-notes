# %%
from typing import List

# %% [markdown]
# 方法1：数组2放进数组1尾部，然后整体排序。快排，时间复杂度O（（m+n）log（m+n））

# %%
class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        nums1[m:]=nums2
        nums1.sort()

# %% [markdown]
# 方法2：正向双指针，两个队列每次取最小的出来。时间复杂度O(m+n),空间也一样，因为新定义数组

# %%
class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        temp=[]
        p1,p2=0,0
        while p1<m or p2<n:
            if p1==m:
                temp.append(nums2[p2])
                p2+=1
            elif p2==n:
                temp.append(nums1[p1])
                p1+=1
            elif nums1[p1]<nums2[p2]:
                temp.append(nums1[p1])
                p1+=1
            else:
                temp.append(nums2[p2])
                p2+=1
        nums1[:]=temp

# %% [markdown]
# 方法3：逆向双指针，空间复杂度O(1)。填充0不会覆盖原有数据

# %%
class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        p1,p2=m-1,n-1
        tail=m+n-1
        while p1>=0 or p2>=0:
            if p1==-1:
                nums1[tail]=nums2[p2]
                p2-=1
            elif p2==-1:
                nums1[tail]=nums1[p1]
                p1-=1
            elif nums1[p1]>nums2[p2]:
                nums1[tail]=nums1[p1]
                p1-=1
            else:
                nums1[tail]=nums2[p2]
                p2-=1
            tail-=1

# %% [markdown]
# test

# %%
if __name__ == "__main__":
    sol = Solution()

    # 用例1
    nums1 = [1,2,3,0,0,0]
    sol.merge(nums1,3,[2,5,6],3)
    assert nums1 == [1,2,2,3,5,6], f"用例1错误，结果:{nums1}"
    print("用例1通过")

    # 用例2
    nums1 = [1,2,3]
    sol.merge(nums1,3,[],0)
    assert nums1 == [1,2,3]
    print("用例2通过")
# Out:
# 用例1通过
# 用例2通过
